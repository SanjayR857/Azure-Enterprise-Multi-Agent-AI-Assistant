# %%
from dotenv import load_dotenv
import os

load_dotenv()

OLLAMA_API_KEY = os.getenv("OLLAMA_API_KEY")

# %%
from langchain_ollama import ChatOllama

model = ChatOllama(
    model="gemma4:31b-cloud",
    temperature=0,
)

# %%
print(model.invoke("Hello which model are you using"))
# Out:
# content='I am a large language model, trained by Google.' additional_kwargs={} response_metadata={'model': 'gemma4:31b', 'created_at': '2026-05-19T17:28:44.27854164Z', 'done': True, 'done_reason': 'stop', 'total_duration': 1702682512, 'load_duration': None, 'prompt_eval_count': 19, 'prompt_eval_duration': None, 'eval_count': 12, 'eval_duration': None, 'logprobs': None, 'model_name': 'gemma4:31b', 'model_provider': 'ollama'} id='lc_run--019e4148-5e09-7331-9141-6cedcf183f10-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 19, 'output_tokens': 12, 'total_tokens': 31}
