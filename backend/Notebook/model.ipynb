# %%
from dotenv import load_dotenv
import os 
from langchain_ollama import ChatOllama
load_dotenv()

model = ChatOllama(
    model="gemma4:31b-cloud",
    temperature=0.7,
    num_predict=256,
)

# %%
response = model.invoke("What is the time today")

# %%
response
# Out:
# AIMessage(content="I do not have access to your local time or a real-time clock. Please check your device's clock for the current time.", additional_kwargs={}, response_metadata={'model': 'gemma4:31b', 'created_at': '2026-05-25T11:26:30.566884813Z', 'done': True, 'done_reason': 'stop', 'total_duration': 7496034696, 'load_duration': None, 'prompt_eval_count': 18, 'prompt_eval_duration': None, 'eval_count': 29, 'eval_duration': None, 'logprobs': None, 'model_name': 'gemma4:31b', 'model_provider': 'ollama'}, id='lc_run--019e5ee2-cf96-7f90-b2ec-67dcb599f453-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 18, 'output_tokens': 29, 'total_tokens': 47})

# %%
from langchain.agents import create_agent
from langchain.messages import  HumanMessage

agent = create_agent(
    model = model
)

# %%
response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?")]}
)

# %%
response
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='7f78e87c-b764-450c-8ba6-2658f42f47ca'),
#   AIMessage(content='The Moon does not have a capital because it is not a country and has no government. It is not inhabited by any sovereign state.\n\nUnder the **Outer Space Treaty of 1967**, which has been signed by most nations on Earth, no country can claim ownership of the Moon or any other celestial body. Therefore, there are no cities, governments, or capitals there.', additional_kwargs={}, response_metadata={'model': 'gemma4:31b', 'created_at': '2026-05-25T11:26:35.119425375Z', 'done': True, 'done_reason': 'stop', 'total_duration': 783054093, 'load_duration': None, 'prompt_eval_count': 22, 'prompt_eval_duration': None, 'eval_count': 79, 'eval_duration': None, 'logprobs': None, 'model_name': 'gemma4:31b', 'model_provider': 'ollama'}, id='lc_run--019e5ee2-f851-7670-8127-5fbdd925cfe0-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 22, 'output_tokens': 79, 'total_tokens': 101})]}
